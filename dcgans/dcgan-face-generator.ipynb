# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import torch 
import torch.nn as nn 
import torch.nn.functional as F 
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms 
import pickle as pkl
import torchvision.utils as vutils

# %%
dataroot='data_faces/'
dataset=datasets.ImageFolder(
    root=dataroot,
    transform=transforms.Compose([
        transforms.Resize(64),
        transforms.CenterCrop(64),
        transforms.ToTensor(),
        transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
        ])
        )

dataloader=DataLoader(dataset,num_workers=0,batch_size=128,shuffle=True)

# %%
real_batch = next(iter(dataloader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0][:64], padding=2, normalize=True).cpu(),(1,2,0)))
plt.show()

# %%
def conv(in_channels,out_channels,kernel_size,stride=2,padding=1,batch_norm=True):
    layers=[]
    conv=nn.Conv2d(in_channels,out_channels,kernel_size,stride,padding,bias=False)

    layers.append(conv)

    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))

    return nn.Sequential(*layers)

# %%
def deconv(in_channels,out_channels,kernel_size,stride=2,padding=1,batch_norm=True):
    layers=[]
    transpose_conv=nn.ConvTranspose2d(in_channels,out_channels,kernel_size,stride,padding,bias=False)

    layers.append(transpose_conv)

    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))

    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):
    def __init__(self,conv_dim):
        super(Discriminator,self).__init__()
        self.conv_dim=conv_dim

        self.conv1=conv(3,conv_dim,4,batch_norm=True)
        self.conv2=conv(conv_dim,conv_dim*2,4,batch_norm=True)
        self.conv3=conv(conv_dim*2,conv_dim*4,4,batch_norm=True)
        self.conv4=conv(conv_dim*4,conv_dim*8,4,batch_norm=False)

        self.fc=nn.Linear(conv_dim*8*2*2,1)


    def forward(self,x):
        x=F.leaky_relu(self.conv1(x),0.2)
        x=F.leaky_relu(self.conv2(x),0.2)
        x=F.leaky_relu(self.conv3(x),0.2)
        x=F.leaky_relu(self.conv4(x),0.2)
        x = x.view(-1, self.conv_dim*8*2*2)
        out=self.fc(x)
        return out

# %%
class Generator(nn.Module):
    def __init__(self,z_size,conv_dim):
        super(Generator,self).__init__()
        self.conv_dim=conv_dim
        self.fc = nn.Linear(z_size,conv_dim*8*2*2)

        self.deconv1 = deconv(conv_dim*8,conv_dim*4,4)
        self.deconv2 = deconv(conv_dim*4,conv_dim*2,4)
        self.deconv3 = deconv(conv_dim*2,conv_dim,4)
        self.deconv4 = deconv(conv_dim,3,4,batch_norm=False)

    def forward(self,x):
        x = self.fc(x)
        x = x.view(-1, self.conv_dim*8, 2, 2)
        x = F.relu(self.deconv1(x))
        x = F.relu(self.deconv2(x))
        x = F.relu(self.deconv3(x))
        x = self.deconv4(x)
        out = F.tanh(x)
        return out

# %%
def weights_init_normal(m):

    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # Applying initial weights to convolutional and linear layers
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        m.weight.data.normal_(0.0, 0.02)
        
        # The bias terms, if they exist, set to 0
        if hasattr(m, 'bias') and m.bias is not None:
            m.bias.data.zero_()

z_size=100
D=Discriminator(64)
G=Generator(z_size,64)

D.apply(weights_init_normal),G.apply(weights_init_normal)

use_cuda=True
if use_cuda and torch.cuda.is_available():
    D.cuda()
    G.cuda()

print(f"{D}\n\n\n{G}\n\n\nGPU on:{use_cuda and torch.cuda.is_available()}")
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv4): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )
#
#
# GPU on:False

# %%
def real_loss(D_out):
    batch_size = D_out.size(0)
        
    labels = torch.ones(batch_size) * 0.9

    if use_cuda and torch.cuda.is_available():
            labels = labels.cuda()
    criterion=nn.BCEWithLogitsLoss()
    loss=criterion(D_out.squeeze(),labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)
        
    labels = torch.ones(batch_size)

    if use_cuda and torch.cuda.is_available():
            labels = labels.cuda()
    criterion=nn.BCEWithLogitsLoss()
    loss=criterion(D_out.squeeze(),labels)
    return loss    
  
  
d_optimizer = optim.Adam(D.parameters(),lr=0.002,betas=(0.5,0.999))
g_optimizer = optim.Adam(G.parameters(),lr=0.002,betas=(0.5,0.999))

# %%
def train(D, G, n_epochs, print_every=300):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if use_cuda and torch.cuda.is_available():
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if use_cuda and torch.cuda.is_available():
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(dataloader):

            batch_size = real_images.size(0)
            #real_images = scale(real_images)

            d_optimizer.zero_grad()
            
            if use_cuda and torch.cuda.is_available():
                real_images = real_images.cuda()
                
            # 1. Train the discriminator on real and fake images
            
            # Compute the discriminator losses on real images
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            
            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if use_cuda and torch.cuda.is_available():
                z = z.cuda()
            fake_images = G(z)
            
            # Compute the discriminator losses on fake images
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            
            # add up loss and perform backprop
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if use_cuda and torch.cuda.is_available():
                z = z.cuda()
            fake_images = G(z)
            
            # Compute the discriminator losses on fake images 
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake)
            
            # perfom backprop
            g_loss.backward()
            g_optimizer.step()


            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses
  
  

n_epochs = 50

# %%
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   50] | d_loss: 1.2242 | g_loss: 0.3795
# Epoch [    1/   50] | d_loss: 0.3263 | g_loss: 0.9391
# Epoch [    1/   50] | d_loss: 0.3256 | g_loss: 1.0202
# Epoch [    1/   50] | d_loss: 0.3257 | g_loss: 1.0954
# Epoch [    1/   50] | d_loss: 0.3253 | g_loss: 1.1175
# Epoch [    1/   50] | d_loss: 0.3259 | g_loss: 1.1306
# Epoch [    2/   50] | d_loss: 0.3254 | g_loss: 1.1479
# Epoch [    2/   50] | d_loss: 0.3253 | g_loss: 1.1484
# Epoch [    2/   50] | d_loss: 0.3253 | g_loss: 1.1754
# Epoch [    2/   50] | d_loss: 0.3253 | g_loss: 1.2013
# Epoch [    2/   50] | d_loss: 0.3252 | g_loss: 1.2010
# Epoch [    2/   50] | d_loss: 0.3252 | g_loss: 1.2358
# Epoch [    3/   50] | d_loss: 0.3254 | g_loss: 1.2102
# Epoch [    3/   50] | d_loss: 0.3252 | g_loss: 1.1418
# Epoch [    3/   50] | d_loss: 0.3252 | g_loss: 1.2283
# Epoch [    3/   50] | d_loss: 0.3253 | g_loss: 1.2269
# Epoch [    3/   50] | d_loss: 0.3254 | g_loss: 1.2087
# Epoch [    3/   50] | d_loss: 0.3252 | g_loss: 1.1901
# Epoch [    4/   50] | d_loss: 0.3252 | g_loss: 1.2440
# Epoch [    4/   50] | d_loss: 0.3253 | g_loss: 1.1477
# Epoch [    4/   50] | d_loss: 0.3253 | g_loss: 1.2153
# Epoch [    4/   50] | d_loss: 0.3253 | g_loss: 1.1964
# Epoch [    4/   50] | d_loss: 0.3252 | g_loss: 1.4249
# Epoch [    4/   50] | d_loss: 0.3252 | g_loss: 1.4386
# Epoch [    5/   50] | d_loss: 0.3254 | g_loss: 1.3549
# Epoch [    5/   50] | d_loss: 0.3252 | g_loss: 1.3041
# Epoch [    5/   50] | d_loss: 0.3251 | g_loss: 1.3024
# Epoch [    5/   50] | d_loss: 0.3252 | g_loss: 1.3000
# Epoch [    5/   50] | d_loss: 0.3251 | g_loss: 1.2288
# Epoch [    5/   50] | d_loss: 0.3252 | g_loss: 1.2562
# Epoch [    6/   50] | d_loss: 0.3254 | g_loss: 1.3168
# Epoch [    6/   50] | d_loss: 0.3253 | g_loss: 1.2328
# Epoch [    6/   50] | d_loss: 0.3253 | g_loss: 1.3009
# Epoch [    6/   50] | d_loss: 0.3251 | g_loss: 1.3178
# Epoch [    6/   50] | d_loss: 0.3251 | g_loss: 1.3058
# Epoch [    6/   50] | d_loss: 0.3252 | g_loss: 1.3408
# Epoch [    7/   50] | d_loss: 0.3251 | g_loss: 1.3061
# Epoch [    7/   50] | d_loss: 0.3251 | g_loss: 1.3888
# Epoch [    7/   50] | d_loss: 0.3252 | g_loss: 1.2659
# Epoch [    7/   50] | d_loss: 0.3252 | g_loss: 1.4337
# Epoch [    7/   50] | d_loss: 0.3251 | g_loss: 1.3064
# Epoch [    7/   50] | d_loss: 0.3252 | g_loss: 1.3593
# Epoch [    8/   50] | d_loss: 0.3252 | g_loss: 1.3567
# Epoch [    8/   50] | d_loss: 0.3252 | g_loss: 1.3141
# Epoch [    8/   50] | d_loss: 0.3252 | g_loss: 1.3015
# Epoch [    8/   50] | d_loss: 0.3253 | g_loss: 1.2688
# Epoch [    8/   50] | d_loss: 0.3253 | g_loss: 1.3443
# Epoch [    8/   50] | d_loss: 0.3252 | g_loss: 1.3249
# Epoch [    9/   50] | d_loss: 0.3251 | g_loss: 1.3350
# Epoch [    9/   50] | d_loss: 0.3253 | g_loss: 1.3072
# Epoch [    9/   50] | d_loss: 0.3251 | g_loss: 1.3561
# Epoch [    9/   50] | d_loss: 0.3253 | g_loss: 1.3194
# Epoch [    9/   50] | d_loss: 0.3251 | g_loss: 1.4584
# Epoch [    9/   50] | d_loss: 0.3251 | g_loss: 1.3956
# Epoch [   10/   50] | d_loss: 0.3252 | g_loss: 1.2991
# Epoch [   10/   50] | d_loss: 0.3251 | g_loss: 1.4116
# Epoch [   10/   50] | d_loss: 0.3251 | g_loss: 1.3957
# Epoch [   10/   50] | d_loss: 0.3251 | g_loss: 1.3197
# Epoch [   10/   50] | d_loss: 0.3251 | g_loss: 1.4007
# Epoch [   10/   50] | d_loss: 0.3253 | g_loss: 1.3720
# Epoch [   11/   50] | d_loss: 0.3251 | g_loss: 1.3898
# Epoch [   11/   50] | d_loss: 0.3251 | g_loss: 1.4041
# Epoch [   11/   50] | d_loss: 0.3251 | g_loss: 1.3847
# Epoch [   11/   50] | d_loss: 0.3251 | g_loss: 1.4007
# Epoch [   11/   50] | d_loss: 0.3252 | g_loss: 1.0997
# Epoch [   11/   50] | d_loss: 0.3251 | g_loss: 1.1546
# Epoch [   12/   50] | d_loss: 0.3251 | g_loss: 1.1827
# Epoch [   12/   50] | d_loss: 0.3251 | g_loss: 1.2482
# Epoch [   12/   50] | d_loss: 0.3251 | g_loss: 1.2909
# Epoch [   12/   50] | d_loss: 0.3251 | g_loss: 1.3102
# Epoch [   12/   50] | d_loss: 0.3251 | g_loss: 1.3648
# Epoch [   12/   50] | d_loss: 0.3252 | g_loss: 1.3651
# Epoch [   13/   50] | d_loss: 0.3251 | g_loss: 1.3514
# Epoch [   13/   50] | d_loss: 0.3251 | g_loss: 1.3958
# Epoch [   13/   50] | d_loss: 0.3252 | g_loss: 1.4070
# Epoch [   13/   50] | d_loss: 0.3251 | g_loss: 1.3946
# Epoch [   13/   50] | d_loss: 0.3251 | g_loss: 1.3970
# Epoch [   13/   50] | d_loss: 0.3253 | g_loss: 1.4203
# Epoch [   14/   50] | d_loss: 0.3251 | g_loss: 1.4070
# Epoch [   14/   50] | d_loss: 0.3253 | g_loss: 1.4306
# Epoch [   14/   50] | d_loss: 0.3251 | g_loss: 1.4046
# Epoch [   14/   50] | d_loss: 0.3251 | g_loss: 1.3817
# Epoch [   14/   50] | d_loss: 0.3251 | g_loss: 1.4916
# Epoch [   14/   50] | d_loss: 0.3252 | g_loss: 1.4460
# Epoch [   15/   50] | d_loss: 0.3251 | g_loss: 1.4499
# Epoch [   15/   50] | d_loss: 0.3251 | g_loss: 1.3930
# Epoch [   15/   50] | d_loss: 0.3251 | g_loss: 1.4311
# Epoch [   15/   50] | d_loss: 0.3252 | g_loss: 1.4476
# Epoch [   15/   50] | d_loss: 0.3253 | g_loss: 1.4462
# Epoch [   15/   50] | d_loss: 0.3251 | g_loss: 1.4091
# Epoch [   16/   50] | d_loss: 0.3251 | g_loss: 1.4119
# Epoch [   16/   50] | d_loss: 0.3251 | g_loss: 1.4495
# Epoch [   16/   50] | d_loss: 0.3251 | g_loss: 1.4492
# Epoch [   16/   50] | d_loss: 0.3252 | g_loss: 1.4451
# Epoch [   16/   50] | d_loss: 0.3251 | g_loss: 1.4492
# Epoch [   16/   50] | d_loss: 0.3251 | g_loss: 1.4647
# Epoch [   17/   50] | d_loss: 0.3251 | g_loss: 1.4470
# Epoch [   17/   50] | d_loss: 0.3251 | g_loss: 1.4492
# Epoch [   17/   50] | d_loss: 0.3252 | g_loss: 1.4383
# Epoch [   17/   50] | d_loss: 0.3251 | g_loss: 1.4545
# Epoch [   17/   50] | d_loss: 0.3252 | g_loss: 1.4542
# Epoch [   17/   50] | d_loss: 0.3251 | g_loss: 1.4203
# Epoch [   18/   50] | d_loss: 0.3252 | g_loss: 1.4452
# Epoch [   18/   50] | d_loss: 0.3253 | g_loss: 1.4412
# Epoch [   18/   50] | d_loss: 0.3251 | g_loss: 1.4279
# Epoch [   18/   50] | d_loss: 0.3251 | g_loss: 1.4337
# Epoch [   18/   50] | d_loss: 0.3251 | g_loss: 1.4285
# Epoch [   18/   50] | d_loss: 0.3251 | g_loss: 1.4446
# Epoch [   19/   50] | d_loss: 0.3251 | g_loss: 1.4405
# Epoch [   19/   50] | d_loss: 0.3251 | g_loss: 1.4374
# Epoch [   19/   50] | d_loss: 0.3251 | g_loss: 1.4227
# Epoch [   19/   50] | d_loss: 0.3251 | g_loss: 1.4375
# Epoch [   19/   50] | d_loss: 0.3251 | g_loss: 1.4468
# Epoch [   19/   50] | d_loss: 0.3251 | g_loss: 1.4467
# Epoch [   20/   50] | d_loss: 0.3252 | g_loss: 1.4581
# Epoch [   20/   50] | d_loss: 0.3252 | g_loss: 1.4477
# Epoch [   20/   50] | d_loss: 0.3252 | g_loss: 1.0769
# Epoch [   20/   50] | d_loss: 0.3251 | g_loss: 1.1502
# Epoch [   20/   50] | d_loss: 0.3251 | g_loss: 1.2684
# Epoch [   20/   50] | d_loss: 0.3251 | g_loss: 1.6744
# Epoch [   21/   50] | d_loss: 0.3253 | g_loss: 1.2509
# Epoch [   21/   50] | d_loss: 0.3251 | g_loss: 1.2828
# Epoch [   21/   50] | d_loss: 0.3251 | g_loss: 1.2769
# Epoch [   21/   50] | d_loss: 0.3251 | g_loss: 1.2570
# Epoch [   21/   50] | d_loss: 0.3251 | g_loss: 1.3449
# Epoch [   21/   50] | d_loss: 0.3251 | g_loss: 1.4306
# Epoch [   22/   50] | d_loss: 0.3252 | g_loss: 1.4935
# Epoch [   22/   50] | d_loss: 0.3251 | g_loss: 1.4057
# Epoch [   22/   50] | d_loss: 0.3251 | g_loss: 1.3927
# Epoch [   22/   50] | d_loss: 0.3251 | g_loss: 1.3959
# Epoch [   22/   50] | d_loss: 0.3251 | g_loss: 1.4305
# Epoch [   22/   50] | d_loss: 0.3251 | g_loss: 1.4461
# Epoch [   23/   50] | d_loss: 0.3251 | g_loss: 1.4402
# Epoch [   23/   50] | d_loss: 0.3251 | g_loss: 1.4381
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 losses = train(D, G, n_epochs=n_epochs)
#
# Cell In[64], line 44, in train(D, G, n_epochs, print_every)
#      39     real_images = real_images.cuda()
#      41 # 1. Train the discriminator on real and fake images
#      42
#      43 # Compute the discriminator losses on real images
# ---> 44 D_real = D(real_images)
#      45 d_real_loss = real_loss(D_real)
#      47 # Generate fake images
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[60], line 18, in Discriminator.forward(self, x)
#      16 x=F.leaky_relu(self.conv2(x),0.2)
#      17 x=F.leaky_relu(self.conv3(x),0.2)
# ---> 18 x=F.leaky_relu(self.conv4(x),0.2)
#      19 x = x.view(-1, self.conv_dim*8*2*2)
#      20 out=self.fc(x)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img +1)*255 / (2)).astype(np.uint8) # rescale to pixel range (0-255)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)
_ = view_samples(-1, samples)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 with open('train_samples.pkl', 'rb') as f:
#       2     samples = pkl.load(f)
#       3 _ = view_samples(-1, samples)
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train_samples.pkl'
